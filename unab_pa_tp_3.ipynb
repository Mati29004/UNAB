# %% [markdown]
# <a href="https://colab.research.google.com/github/Mati29004/UNAB/blob/main/unab_pa_tp_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Punto:
      def __init__(self, eje_x, eje_y):
        self.eje_x = eje_x
        self.eje_y = eje_y
      def eje_x(self):
          return self.x
      def eje_y(self):
          return self.y
